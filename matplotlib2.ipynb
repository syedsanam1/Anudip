# %%
import matplotlib.pyplot as plt
days=list(range(1,31))
temp=[68,70,72,75,77,80,82,83,81,78,75,72,71,70,72,74,77,79,80,82,84,86,88,87,85,82,80,77,75,73]
plt.plot(days,temp,marker='o')
plt.xlabel("day of month")
plt.ylabel("temperature")
plt.title("daily temperature over month")
plt.show()

# %%
days=list(range(1,31))
stock_prices=[100,105,110,115,112,118,125,128,130,132,145,149,150,153,155,158,160,165,167,169,175,178,180,185,188,190,192,195,199,200]
plt.plot(days,stock_prices,marker='o')
plt.xlabel("days of month")
plt.ylabel("stock value")
plt.title("stock market analysis")
# Out:
# Text(0.5, 1.0, 'stock market analysis')

# %%
days = list(range(1, 79))
stock_prices = [100, 105, 110, 115, 112,118, 125, 128, 130, 132, 135, 138, 140, 142, 144, 145, 148, 150, 155, 160, 158, 162, 165, 170, 172, 175, 178, 180, 182, 162, 160, 158, 155, 152, 150, 148, 145, 143,
185, 188, 190, 192, 195, 198,
200, 198, 195, 193, 190, 188,
185, 182, 180, 178, 175, 172,170, 168, 165,
140, 138, 135, 132, 130, 128,
125, 123, 120, 118, 115, 112,
110, 108, 105, 103,100,99,98]
plt.plot(days,stock_prices)
plt.xlabel("days of month")
plt.ylabel("stock value")
plt.title("stock market analysis")
# Out:
# Text(0.5, 1.0, 'stock market analysis')

# %%
categories=['rent','groceries','utilities','entertainment','transportation']
expense=[1200,400,200,150,250]
plt.bar(categories,expense)
plt.xlabel('categories')
plt.ylabel("total expenditure")
plt.title("Analysis report")
# Out:
# Text(0.5, 1.0, 'Analysis report')

# %%
#piechart

# %%
manufacture=['samsung','apple','vivo','huawei','others']
market_share=[15,25,10,15,15]
plt.pie(market_share,labels=manufacture)
plt.title("smartphone market share")
# Out:
# Text(0.5, 1.0, 'smartphone market share')

# %%
income=['salary','freelance','investments','rental','others']
monthy_income=[5000,1500,1000,600,400]
plt.pie(monthy_income,labels=income)
plt.title("sources of income")
# Out:
# Text(0.5, 1.0, 'sources of income')

# %%
segments=['productA','productB','services','licensing']
revenue_precentages=[45,25,15,15]
plt.pie(revenue_precentages,labels=segments)
plt.title("Revenue Analysis")
# Out:
# Text(0.5, 1.0, 'Revenue Analysis')

# %%
#scatterplot

# %%
study_hours=[2,3,1,4,2,8,20,10,50,60]
exam_hours=[80,90,50,92,66,89,95,100,92,90]
plt.scatter(study_hours,exam_hours)
plt.xlabel('study_hours')
plt.ylabel('exam_hours')    
plt.title('study_hours Vs study_hours')
# Out:
# Text(0.5, 1.0, 'study_hours Vs study_hours')

# %%
square_footage=[1200,1400,1600,1800,2000,2200,2400,2600,2800,3000]
selling_prices=[250,290,315,380,410,450,500,525,570,610]
plt.scatter(square_footage,selling_prices)
plt.xlabel('square_footage')
plt.ylabel('selling_prices')
plt.title('square_footage Vs selling_prices')
# Out:
# Text(0.5, 1.0, 'square_footage Vs selling_prices')

# %%
categories=['rent','food','transport','entertainment','saving']
values=[35,25,15,10,15]
plt.pie(values,labels=categories)
plt.xlabel('categories')
plt.ylabel('values')
plt.title('categories Vs values')
# Out:
# Text(0.5, 1.0, 'categories Vs values')
